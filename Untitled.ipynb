# %%
from glassdoor_scraper import get_job_posts

# %%
jobs = get_job_posts('Data Scientist', 'Portland')
# Out:
# Searching Glassdoor for  Data Scientist openings in Portland
# Fetching location details
# Total job pages found: 7
# Total job listings found: 196

# %%
jobs['Company'] = jobs['Company'].apply(lambda x : x[0])

# %%
jobs
# Out:
#                                    Company  \
# 0                                 ProKarma
# 1                             The Standard
# 2                              DiscoverOrg
# 3                                   Simple
# 4          First Tech Federal Credit Union
# 5                                 Goldstar
# 6                                     Nike
# 7                              Slalom LLC.
# 8          First Tech Federal Credit Union
# 9                        Vesta Corporation
# 10                                ProKarma
# 11                            Diverse Lynx
# 12                        General Assembly
# 13                                comScore
# 14                            Apex Systems
# 15                     Profocus Technology
# 16                                  Oracle
# 17                            VanderHouwen
# 18                                Yieldbot
# 19                                    Nike
# 20                            CoStar Group
# ...
